# %%
import pandas as pd

df = pd.read_csv("data_1.csv")

df["new_quantity "] = df["quantity"].apply(lambda x: x+1)

print(df["new_quantity "])
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       3
#        ..
# 4617    2
# 4618    2
# 4619    2
# 4620    2
# 4621    2
# Name: new_quantity , Length: 4622, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("data_1.csv")

def incr(x):
    if x > 10:
        x+1
    else:
        x+=3
        
    return x

df["new_price"] = df["item_price"].apply(incr)

print(df["new_price"])

# %%
import pandas as pd

df = pd.read_csv("data_1.csv")

def incr(x):
    if x > 10:
        x+1
    else:
        x+=3
        
    return x

df["new_price"] = df["item_price"].apply(incr)

print(df["new_price"])

# %%
import pandas as pd

df = pd.read_csv("data_1.csv")

df["item_name"].uniique() 
df["item_name"].nuniique() 

print(df["new_price"])

# %%
# group by 

z = df.groupby('item_name')

y = z.get_group('Canned Soda')

print(y)

# %%
.conncat()

.merge()

    how={'inner'
         'outer'
         'left'
         'right'
         'cross'}

.join()
