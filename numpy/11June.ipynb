# %%
# aap shaant ho , pareshaan ho , bohooot kuch hai man mein , bohooot saari baate  hain , uljhane hain jo shayad aap khud bhee nhi samjh paa rahe ho or na 
# kisi ko samjhaa ya bata paa rahe ho isiliye aap andhar se bhare huye ho aap ko bass thodi shaantni chahaiye jaan ,
# you need to take a rest and need to don't give tension through overthinking to your body and mind , bass aap ko bina bole samjhe or aap ko aap k moods ka
# saari situation ka dhyaan rakhu

# %%
import numpy as np

a = np.array([[
              [1,2],
              [3,4],
              ],
              [
                [5,6],
                [7,8],
                ]])

print(a.shape)
print(a.ndim) #
print(a[1,1,1])
print(a[1,0,1])
print(a[-1,-2,-2])
print(a[-2,-1,-2])
print(a[-2,-2,-1])

# slicing
print(a[:1,0:,0:])
print(a[1:,0:,0:])
print(a[0:,:1,0:])
print(end='\n')
print(a[:,:,-1:])
print(a[-1,:,:])
print(a[:,:,-1:])
print(a[-1,-1,:])
print(a[-2,-1,:])
print(a[-2:,-1,:])
print(a[-2:,-2,-1])
# Out:
# [2 6]

# %%
import numpy as np

a = np.array([1,2,3,4])
print(np.median(a))
# Out:
# 2.5
